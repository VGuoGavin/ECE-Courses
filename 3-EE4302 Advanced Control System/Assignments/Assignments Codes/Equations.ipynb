# %% [markdown]
# # EE 4302 CA

# %% [markdown]
# # CA1 Ackerman formual calculation

# %% [markdown]
# $$
# \zeta =
# { {\begin{bmatrix}
#      G  & FG
# \end{bmatrix}} }
# =
# { {\begin{bmatrix}
#      0  &  1 \\
#      1 &  -3.71
# \end{bmatrix}} }
# $$
#
# $$
# rank(\zeta) = 2
# $$
#
#
# $$
# \alpha_c(s) = s^2 + 6.43s +  16.1506 \\
# \alpha_c(F) = F^2 + 6.43F +  16.1506I \\
# =
# { {\begin{bmatrix}
#      0  &  1 \\
#    -1.2 &  -3.71
# \end{bmatrix}} }^2 +
# 6.43{ {\begin{bmatrix}
#      0  &  1 \\
#    -1.2 &  -3.71
# \end{bmatrix}} }+
# { {\begin{bmatrix}
#      16.1506  &  0 \\
#    0 &  16.1506
# \end{bmatrix}} }
# $$
#
# $$
# K = [0 1]\zeta^{-1}\alpha_c(F) =
# { {\begin{bmatrix}
#      14.9506  & 2.72
# \end{bmatrix}} }
# $$
#
# no scaling gain state space:
# $$
# \dot{ {\begin{bmatrix}
# x_1\\
# x_2
# \end{bmatrix}} } =
# {\begin{bmatrix}
# 0    &  1    \\
# -16.15 & -6.43
# \end{bmatrix}}
# { {\begin{bmatrix}
# x_1\\
# x_2
# \end{bmatrix}} }  +
# {\begin{bmatrix}
# 0\\
# 1
# \end{bmatrix}} u
# $$
#
#
# $$
# G =  \frac{1}{s^2+6.43s+16.1506}
# $$
#
# $$
# s = 0 \\
# G(0) = \frac{1}{16.1506}\\
#
# $$

# %% [markdown]
# # LQR part

# %% [markdown]
# $$
# Q =
# { {\begin{bmatrix}
#      10  &  0 \\
#    0 &  10
# \end{bmatrix}} }
# $$
#
# $$
# R = 1
# $$

# %% [markdown]
# $$
# \dot{ {\begin{bmatrix}
# x_1\\
# x_2
# \end{bmatrix}} } =
# {\begin{bmatrix}
# 0    &  1    \\
# -1.2 & -3.71
# \end{bmatrix}}
# { {\begin{bmatrix}
# x_1\\
# x_2
# \end{bmatrix}} }  +
# {\begin{bmatrix}
# 0\\
# 1
# \end{bmatrix}} u
# $$
#
# $$
# y = {\begin{bmatrix}
# 1 & 0
# \end{bmatrix}} { {\begin{bmatrix}
# x_1\\
# x_2
# \end{bmatrix}} }
# $$
# $$
# F = A = {\begin{bmatrix}
# 0    &  1    \\
# -1.2 & -3.71
# \end{bmatrix}};\
# G=B = {\begin{bmatrix}
# 0\\
# 1
# \end{bmatrix}} ;\
# H=C = {\begin{bmatrix}
# 1\\
# 0
# \end{bmatrix}}
# $$
# $$
# \begin{cases}
# u = -k_1 x_1 -k_2x_2 = 0.1x_1-0.1x_2 \\
# y = Ku = {\begin{bmatrix}
# 0.1 & 0.1
# \end{bmatrix}} {\begin{bmatrix}
# x_1\\
# x_2
# \end{bmatrix}}
# \end{cases}
# $$
#
# $$
# u = -k_1 x_1 -k_2 x_2 = 0.1x_1 - 0.1x_2 + r \\
# u = {\begin{bmatrix}
# 0.1 & 0.1
# \end{bmatrix}} {\begin{bmatrix}
# x_1\\
# x_2
# \end{bmatrix}} + r
# $$

# %% [markdown]
# $$
# \begin{cases}
# \hat{G}(s) = \frac{w_n^2}{s^2+2 \xi w_n + w_n^2} \\
# W_b = w_n \sqrt{1-2\xi^2 + \sqrt{ 2-4\xi^2 + 4\xi^4}} > 3.5\\
# W_r = w_n \sqrt{1-2\xi ^2}
# \end{cases}
#
# $$
# Calculating by hand:
# $$
# \frac{2-\sqrt{2}}{2} < \xi^2 < \frac{2+\sqrt{2}}{2}  \Rightarrow
# \begin{cases}
# -1.8478 < \xi < -0.7654 \\
#  1.8478 > \xi > 0.7654
# \end{cases}
# $$
# let $ \xi $ = 0.8 $\Rightarrow\ w_n = 4.0188$

# %% [markdown]
# $$
# \dot{x}_I = y-r = x_1 - r
# $$
#
# $$
# \dot{ {\begin{bmatrix}
# x_1\\
# x_2\\
# x_I
# \end{bmatrix}} } =
# {\begin{bmatrix}
# 0    &  1    & 0 \\
# -1.2 & -3.71 & 0 \\
# 1 &  0    & 0
# \end{bmatrix}}
# { {\begin{bmatrix}
# x_1\\
# x_2\\
# x_I
# \end{bmatrix}} }  +
# {\begin{bmatrix}
# 0\\
# 1\\
# 0
# \end{bmatrix}}  u +
#
# {\begin{bmatrix}
# 0\\
# 0\\
# -1
# \end{bmatrix}} r +
#
# {\begin{bmatrix}
# 0\\
# 1\\
# 0
# \end{bmatrix}}v
# $$
# $$
# y = {\begin{bmatrix}
# 1 & 0 & 0
# \end{bmatrix}}
# {\begin{bmatrix}
# x_1\\
# x_2\\
# x_I
# \end{bmatrix}}
# $$

# %% [markdown]
# $$
# F = A = {\begin{bmatrix}
# 0    &  1    & 0 \\
# -1.2 & -3.71 & 0 \\
# 1 &  0    & 0
# \end{bmatrix}};\
#
# H=C = {\begin{bmatrix}
# 1\\
# 0\\
# 0
# \end{bmatrix}}
# $$
#
# $$
# G_u= B_u= {\begin{bmatrix}
# 0\\
# 1\\
# 0
# \end{bmatrix}} ;\
# G_r= B_r= {\begin{bmatrix}
# 0\\
# 0\\
# -1
# \end{bmatrix}} ;\
# G_v= B_v= {\begin{bmatrix}
# 0\\
# 1\\
# 0
# \end{bmatrix}}
# $$

# %% [markdown]
# $$
# W_c =
# { {\begin{bmatrix}
#      G  & FG & F^2G
#
# \end{bmatrix}} }
# $$

# %% [markdown]
# $$
#  0.26 < \sigma < 0.97
# $$
#
# $$
# \sigma = 0.5
# $$
#
#
# $$
# w_b = w_n\sqrt{1-2\sigma^2 + \sqrt{2-4\sigma^2+4\sigma^4}} > 2
# $$
# $$
# w_n = 1.6
# $$

# %% [markdown]
# $$
# s^2 + 2\sigma w_n s + w_n^2 = 0
# $$
#
# $$
# [-5,\ -0.8-1.4i,\ -0.8+1.4i]
# $$

# %% [markdown]
# # MIMO Exploration

# %% [markdown]
# $$
# \dot{ {\begin{bmatrix}
# x_1\\
# x_2
# \end{bmatrix}} } =
# {\begin{bmatrix}
# 0    &  1    \\
# -1.2 & -3.71
# \end{bmatrix}}
# { {\begin{bmatrix}
# x_1\\
# x_2
# \end{bmatrix}} }  +
# {\begin{bmatrix}
# 1&0\\
# 0&2
# \end{bmatrix}} u
# $$
#
# $$
# y = {\begin{bmatrix}
# 1 & 0
# \end{bmatrix}} { {\begin{bmatrix}
# x_1\\
# x_2
# \end{bmatrix}} }
# $$

# %% [markdown]
# $$
# u =
# { {\begin{bmatrix}
# q_1\\
# q_2
# \end{bmatrix}} }
# v
# $$
#
# $$\dot{x} = Ax + Bu = Ax + Bqu$$
#
# $$
# q = { {\begin{bmatrix}
# 1\\
# 2
# \end{bmatrix}} }
# $$
#
# $$
# v = -k^Tx
# $$
#
# $$
# u = qv = -qk^Tx = -Kx
# $$
#
# $$
# k = [k_1, k_2]
# $$
#
# $$
# K = qk^T =
# { {\begin{bmatrix}
# q_1\\
# q_2
# \end{bmatrix}} }
# { {\begin{bmatrix}
# k_1, k_2
# \end{bmatrix}} }
# $$
